# %% [markdown]
# ### Download the whole repository with ‘git clone https://github.com/dmlc/mxnet-notebooks.git' and run this notebook.
# # Parameter Initializer
#
# https://github.com/dmlc/mxnet/blob/master/python/mxnet/initializer.py
