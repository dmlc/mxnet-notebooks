# %% [markdown]
# # Matrix Factorization
#
# In a recommendation system, there is a group of users and a set of items. Given that each users have rated some items in the system, we would like to predict how the users would rate the items that they have not yet rated, such that we can make recommendations to the users.
#
# Matrix factorization is one of the mainly used algorithm in recommendation systems. It can be used to discover latent features underlying the interactions between two different kinds of entities. Assume we assign a $k$ dimensional vector $u_i$ to user $i$ and $k$ dimensional vector $v_j$ to item $j$, then user $i$ rates movie $j$ by $\langle u_i, v_j\rangle$.
#
# We can learn all $u_i$ and $v_j$ directly, which is essentially performing SVD on the user-item matrix. We can also try to learn the latent features using multi-layer neural networks.
#
# In this tutorial, we will work though the steps to implement these ideas in MXNet.

# %% [markdown]
# ## Prepare Data
#
# We use the [MovieLens](http://grouplens.org/datasets/movielens/) data here, but it can apply to other datasets as well. Each row of this dataset contains a tuple of user id, movie id, rating, and time stamp, we will only use the first three items. We first define the a batch which contains n tuples. It also provides name and shape information to MXNet about the data and label.

# %%
class Batch(object):
    def __init__(self, data_names, data, label_names, label):
        self.data = data
        self.label = label
        self.data_names = data_names
        self.label_names = label_names
        
    @property
    def provide_data(self):
        return [(n, x.shape) for n, x in zip(self.data_names, self.data)]
    
    @property
    def provide_label(self):
        return [(n, x.shape) for n, x in zip(self.label_names, self.label)]

# %% [markdown]
# Then we define a data iterator, which returns a batch of tuples each time.

# %%
import mxnet as mx
import random

class Batch(object):
    def __init__(self, data_names, data, label_names, label):
        self.data = data
        self.label = label
        self.data_names = data_names
        self.label_names = label_names

    @property
    def provide_data(self):
        return [(n, x.shape) for n, x in zip(self.data_names, self.data)]

    @property
    def provide_label(self):
        return [(n, x.shape) for n, x in zip(self.label_names, self.label)]

class DataIter(mx.io.DataIter):
    def __init__(self, fname, batch_size):
        super(DataIter, self).__init__()
        self.batch_size = batch_size
        self.data = []
        for line in file(fname):
            tks = line.strip().split('\t')
            if len(tks) != 4:
                continue
            self.data.append((int(tks[0]), int(tks[1]), float(tks[2])))
        self.provide_data = [('user', (batch_size, )), ('item', (batch_size, ))]
        self.provide_label = [('score', (self.batch_size, ))]

    def __iter__(self):
        for k in range(len(self.data) / self.batch_size):
            users = []
            items = []
            scores = []
            for i in range(self.batch_size):
                j = k * self.batch_size + i
                user, item, score = self.data[j]
                users.append(user)
                items.append(item)
                scores.append(score)

            data_all = [mx.nd.array(users), mx.nd.array(items)]
            label_all = [mx.nd.array(scores)]
            data_names = ['user', 'item']
            label_names = ['score']

            data_batch = Batch(data_names, data_all, label_names, label_all)
            yield data_batch

    def reset(self):
        random.shuffle(self.data)

# %% [markdown]
# Now we download the data and provide a function to obtain the data iterator:

# %%
import os
if not os.path.exists("ml-100k.zip"):
    os.system("wget http://files.grouplens.org/datasets/movielens/ml-100k.zip") 
    os.system("unzip ml-100k.zip")
def get_data(batch_size):
    return (DataIter('./ml-100k/u1.base', batch_size), DataIter('./ml-100k/u1.test', batch_size))

# %% [markdown]
# Finally we calculate the numbers of users and items for later use.

# %%
def max_id(fname):
    mu = 0
    mi = 0
    for line in file(fname):
        tks = line.strip().split('\t')
        if len(tks) != 4:
            continue
        mu = max(mu, int(tks[0]))
        mi = max(mi, int(tks[1]))
    return mu + 1, mi + 1
max_user, max_item = max_id('./ml-100k/u.data')
(max_user, max_item)
# Out:
# (944, 1683)

# %% [markdown]
# ## Optimization
#
# We first implement the RMSE (root-mean-square error) measurement, which is commonly used by matrix factorization.

# %%
import math
def RMSE(label, pred):
    ret = 0.0
    n = 0.0
    pred = pred.flatten()
    for i in range(len(label)):
        ret += (label[i] - pred[i]) * (label[i] - pred[i])
        n += 1.0
    return math.sqrt(ret / n)

# %% [markdown]
# Then we define a general training module, which is borrowed from the image classification application.

# %%
def train(network, batch_size, num_epoch, learning_rate):
    model = mx.model.FeedForward(
        ctx = [mx.gpu(0)],  # can be change to [mx.gpu(0), mx.gpu(1)] if there are 2 gpus
        symbol = network,
        num_epoch = num_epoch,
        learning_rate = learning_rate,
                             #lr_scheduler = mx.lr_scheduler.FactorScheduler(
        #step = max(int(80000/batch_size*2), 1),
         #   factor = 0.95),
        wd = 0.0001,
        #initializer = mx.init.Xavier(factor_type="in", magnitude=2.34),
        momentum = 0.9)

    batch_size = 64
    train, test = get_data(batch_size)

    import logging
    head = '%(asctime)-15s %(message)s'
    logging.basicConfig(level=logging.DEBUG)

    model.fit(X = train, 
              eval_data = test,
              eval_metric = RMSE,
              batch_end_callback=mx.callback.Speedometer(batch_size, 10000/batch_size),)

# %% [markdown]
# ## Networks
#
# Now we try various networks. We first learn the latent vectors directly.

# %%
def plain_net(k):
    # input
    user = mx.symbol.Variable('user')
    item = mx.symbol.Variable('item')
    score = mx.symbol.Variable('score')
    # user feature lookup
    user = mx.symbol.Embedding(data = user, input_dim = max_user, output_dim = k) 
    # item feature lookup
    item = mx.symbol.Embedding(data = item, input_dim = max_item, output_dim = k)
    # predict by the inner product, which is elementwise product and then sum
    pred = user * item
    pred = mx.symbol.sum_axis(data = pred, axis = 1)
    pred = mx.symbol.Flatten(data = pred)
    # loss layer
    pred = mx.symbol.LinearRegressionOutput(data = pred, label = score)
    return pred

train(plain_net(64), batch_size=64, num_epoch=10, learning_rate=.05)
# Out:
# INFO:root:Start training with [gpu(0)]
# INFO:root:Epoch[0] Batch [156]	Speed: 56152.02 samples/sec	Train-RMSE=3.706615
# INFO:root:Epoch[0] Batch [312]	Speed: 56093.35 samples/sec	Train-RMSE=3.697545
# INFO:root:Epoch[0] Batch [468]	Speed: 55999.96 samples/sec	Train-RMSE=3.708319
# INFO:root:Epoch[0] Batch [624]	Speed: 56241.24 samples/sec	Train-RMSE=3.688322
# INFO:root:Epoch[0] Batch [780]	Speed: 55798.34 samples/sec	Train-RMSE=3.704836
# INFO:root:Epoch[0] Batch [936]	Speed: 55368.81 samples/sec	Train-RMSE=3.683681
# INFO:root:Epoch[0] Batch [1092]	Speed: 55267.68 samples/sec	Train-RMSE=3.705261
# INFO:root:Epoch[0] Batch [1248]	Speed: 54383.48 samples/sec	Train-RMSE=3.694059
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=1.477
# INFO:root:Epoch[0] Validation-RMSE=3.713718
# INFO:root:Epoch[1] Batch [156]	Speed: 55056.23 samples/sec	Train-RMSE=3.697979
# INFO:root:Epoch[1] Batch [312]	Speed: 54194.29 samples/sec	Train-RMSE=3.668891
# INFO:root:Epoch[1] Batch [468]	Speed: 54458.23 samples/sec	Train-RMSE=3.642110
# INFO:root:Epoch[1] Batch [624]	Speed: 55428.18 samples/sec	Train-RMSE=3.577095
# INFO:root:Epoch[1] Batch [780]	Speed: 55699.93 samples/sec	Train-RMSE=3.426324
# INFO:root:Epoch[1] Batch [936]	Speed: 55505.17 samples/sec	Train-RMSE=3.084756
# INFO:root:Epoch[1] Batch [1092]	Speed: 55576.92 samples/sec	Train-RMSE=2.704116
# INFO:root:Epoch[1] Batch [1248]	Speed: 54706.81 samples/sec	Train-RMSE=2.379844
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=1.490
# INFO:root:Epoch[1] Validation-RMSE=2.419295
# INFO:root:Epoch[2] Batch [156]	Speed: 49208.89 samples/sec	Train-RMSE=2.110523
# INFO:root:Epoch[2] Batch [312]	Speed: 48535.99 samples/sec	Train-RMSE=1.889097
# INFO:root:Epoch[2] Batch [468]	Speed: 48694.81 samples/sec	Train-RMSE=1.759300
# INFO:root:Epoch[2] Batch [624]	Speed: 48668.72 samples/sec	Train-RMSE=1.647674
# INFO:root:Epoch[2] Batch [780]	Speed: 52903.51 samples/sec	Train-RMSE=1.517060
# INFO:root:Epoch[2] Batch [936]	Speed: 55862.36 samples/sec	Train-RMSE=1.484016
# INFO:root:Epoch[2] Batch [1092]	Speed: 56004.98 samples/sec	Train-RMSE=1.400864
# INFO:root:Epoch[2] Batch [1248]	Speed: 54597.33 samples/sec	Train-RMSE=1.342697
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=1.588
# INFO:root:Epoch[2] Validation-RMSE=1.431981
# INFO:root:Epoch[3] Batch [156]	Speed: 54941.66 samples/sec	Train-RMSE=1.265084
# INFO:root:Epoch[3] Batch [312]	Speed: 54567.87 samples/sec	Train-RMSE=1.264938
# INFO:root:Epoch[3] Batch [468]	Speed: 54376.70 samples/sec	Train-RMSE=1.229487
# INFO:root:Epoch[3] Batch [624]	Speed: 54321.68 samples/sec	Train-RMSE=1.212403
# INFO:root:Epoch[3] Batch [780]	Speed: 53476.68 samples/sec	Train-RMSE=1.166233
# INFO:root:Epoch[3] Batch [936]	Speed: 53950.34 samples/sec	Train-RMSE=1.150932
# INFO:root:Epoch[3] Batch [1092]	Speed: 54338.24 samples/sec	Train-RMSE=1.146948
# INFO:root:Epoch[3] Batch [1248]	Speed: 54033.32 samples/sec	Train-RMSE=1.140070
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=1.513
# INFO:root:Epoch[3] Validation-RMSE=1.202079
# INFO:root:Epoch[4] Batch [156]	Speed: 54793.07 samples/sec	Train-RMSE=1.096710
# INFO:root:Epoch[4] Batch [312]	Speed: 54616.48 samples/sec	Train-RMSE=1.097131
# INFO:root:Epoch[4] Batch [468]	Speed: 54474.31 samples/sec	Train-RMSE=1.098475
# INFO:root:Epoch[4] Batch [624]	Speed: 54543.99 samples/sec	Train-RMSE=1.067425
# INFO:root:Epoch[4] Batch [780]	Speed: 54422.99 samples/sec	Train-RMSE=1.077556
# INFO:root:Epoch[4] Batch [936]	Speed: 54681.38 samples/sec	Train-RMSE=1.063173
# INFO:root:Epoch[4] Batch [1092]	Speed: 55050.15 samples/sec	Train-RMSE=1.058728
# INFO:root:Epoch[4] Batch [1248]	Speed: 54792.14 samples/sec	Train-RMSE=1.052552
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=1.501
# INFO:root:Epoch[4] Validation-RMSE=1.115826
# INFO:root:Epoch[5] Batch [156]	Speed: 49110.90 samples/sec	Train-RMSE=1.022660
# INFO:root:Epoch[5] Batch [312]	Speed: 54949.52 samples/sec	Train-RMSE=1.034606
# INFO:root:Epoch[5] Batch [468]	Speed: 54974.05 samples/sec	Train-RMSE=1.034887
# INFO:root:Epoch[5] Batch [624]	Speed: 54504.02 samples/sec	Train-RMSE=1.028711
# INFO:root:Epoch[5] Batch [780]	Speed: 54669.96 samples/sec	Train-RMSE=1.025565
# INFO:root:Epoch[5] Batch [936]	Speed: 54931.43 samples/sec	Train-RMSE=1.025683
# INFO:root:Epoch[5] Batch [1092]	Speed: 54472.54 samples/sec	Train-RMSE=1.037122
# INFO:root:Epoch[5] Batch [1248]	Speed: 54714.96 samples/sec	Train-RMSE=1.018717
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=1.522
# INFO:root:Epoch[5] Validation-RMSE=1.071941
# INFO:root:Epoch[6] Batch [156]	Speed: 56005.20 samples/sec	Train-RMSE=1.003523
# INFO:root:Epoch[6] Batch [312]	Speed: 55581.20 samples/sec	Train-RMSE=1.000883
# INFO:root:Epoch[6] Batch [468]	Speed: 54543.64 samples/sec	Train-RMSE=0.991006
# INFO:root:Epoch[6] Batch [624]	Speed: 55623.35 samples/sec	Train-RMSE=1.006816
# INFO:root:Epoch[6] Batch [780]	Speed: 55959.70 samples/sec	Train-RMSE=1.010641
# INFO:root:Epoch[6] Batch [936]	Speed: 56006.85 samples/sec	Train-RMSE=1.012411
# INFO:root:Epoch[6] Batch [1092]	Speed: 56219.04 samples/sec	Train-RMSE=1.007607
# INFO:root:Epoch[6] Batch [1248]	Speed: 55977.35 samples/sec	Train-RMSE=1.001625
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=1.475
# INFO:root:Epoch[6] Validation-RMSE=1.049505
# INFO:root:Epoch[7] Batch [156]	Speed: 56863.96 samples/sec	Train-RMSE=0.987829
# INFO:root:Epoch[7] Batch [312]	Speed: 55854.91 samples/sec	Train-RMSE=0.984407
# INFO:root:Epoch[7] Batch [468]	Speed: 56121.09 samples/sec	Train-RMSE=0.993369
# INFO:root:Epoch[7] Batch [624]	Speed: 55779.69 samples/sec	Train-RMSE=0.999314
# INFO:root:Epoch[7] Batch [780]	Speed: 55902.70 samples/sec	Train-RMSE=0.982091
# INFO:root:Epoch[7] Batch [936]	Speed: 55519.08 samples/sec	Train-RMSE=0.988640
# INFO:root:Epoch[7] Batch [1092]	Speed: 55751.99 samples/sec	Train-RMSE=0.997003
# INFO:root:Epoch[7] Batch [1248]	Speed: 55966.88 samples/sec	Train-RMSE=0.986120
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=1.469
# INFO:root:Epoch[7] Validation-RMSE=1.036123
# INFO:root:Epoch[8] Batch [156]	Speed: 56123.57 samples/sec	Train-RMSE=0.968606
# INFO:root:Epoch[8] Batch [312]	Speed: 55761.27 samples/sec	Train-RMSE=0.981268
# INFO:root:Epoch[8] Batch [468]	Speed: 55953.72 samples/sec	Train-RMSE=0.984670
# INFO:root:Epoch[8] Batch [624]	Speed: 43851.58 samples/sec	Train-RMSE=0.973858
# INFO:root:Epoch[8] Batch [780]	Speed: 37403.78 samples/sec	Train-RMSE=0.984366
# INFO:root:Epoch[8] Batch [936]	Speed: 37331.73 samples/sec	Train-RMSE=0.981248
# INFO:root:Epoch[8] Batch [1092]	Speed: 37453.16 samples/sec	Train-RMSE=0.989204
# INFO:root:Epoch[8] Batch [1248]	Speed: 37427.62 samples/sec	Train-RMSE=0.983527
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=1.875
# INFO:root:Epoch[8] Validation-RMSE=1.024367
# INFO:root:Epoch[9] Batch [156]	Speed: 37729.29 samples/sec	Train-RMSE=0.975141
# INFO:root:Epoch[9] Batch [312]	Speed: 37596.04 samples/sec	Train-RMSE=0.967309
# INFO:root:Epoch[9] Batch [468]	Speed: 37445.83 samples/sec	Train-RMSE=0.969378
# INFO:root:Epoch[9] Batch [624]	Speed: 37450.08 samples/sec	Train-RMSE=0.973308
# INFO:root:Epoch[9] Batch [780]	Speed: 37638.41 samples/sec	Train-RMSE=0.987016
# INFO:root:Epoch[9] Batch [936]	Speed: 37573.54 samples/sec	Train-RMSE=0.977451
# INFO:root:Epoch[9] Batch [1092]	Speed: 37399.98 samples/sec	Train-RMSE=0.971797
# INFO:root:Epoch[9] Batch [1248]	Speed: 37465.93 samples/sec	Train-RMSE=0.970934
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=2.174
# INFO:root:Epoch[9] Validation-RMSE=1.017791

# %% [markdown]
# Next we try to use 2 layers neural network to learn the latent variables, which stack a fully connected layer above the embedding layers:

# %%
def get_one_layer_mlp(hidden, k):
    # input
    user = mx.symbol.Variable('user')
    item = mx.symbol.Variable('item')
    score = mx.symbol.Variable('score')
    # user latent features
    user = mx.symbol.Embedding(data = user, input_dim = max_user, output_dim = k)
    user = mx.symbol.FullyConnected(data = user, num_hidden = hidden)
    # item latent features
    item = mx.symbol.Embedding(data = item, input_dim = max_item, output_dim = k)
    item = mx.symbol.FullyConnected(data = item, num_hidden = hidden)
    # predict by the inner product
    pred = user * item
    pred = mx.symbol.sum_axis(data = pred, axis = 1)
    pred = mx.symbol.Flatten(data = pred)
    # loss layer
    pred = mx.symbol.LinearRegressionOutput(data = pred, label = score)
    return pred

train(get_one_layer_mlp(64, 64), batch_size=64, num_epoch=10, learning_rate=.02)
# Out:
# INFO:root:Start training with [gpu(0)]
# INFO:root:Epoch[0] Batch [156]	Speed: 34221.56 samples/sec	Train-RMSE=1.942634
# INFO:root:Epoch[0] Batch [312]	Speed: 30912.80 samples/sec	Train-RMSE=1.119005
# INFO:root:Epoch[0] Batch [468]	Speed: 35044.73 samples/sec	Train-RMSE=1.098399
# INFO:root:Epoch[0] Batch [624]	Speed: 35098.19 samples/sec	Train-RMSE=1.054476
# INFO:root:Epoch[0] Batch [780]	Speed: 35128.96 samples/sec	Train-RMSE=1.011925
# INFO:root:Epoch[0] Batch [936]	Speed: 35080.08 samples/sec	Train-RMSE=0.983108
# INFO:root:Epoch[0] Batch [1092]	Speed: 34945.15 samples/sec	Train-RMSE=0.977220
# INFO:root:Epoch[0] Batch [1248]	Speed: 33966.69 samples/sec	Train-RMSE=0.965951
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=2.376
# INFO:root:Epoch[0] Validation-RMSE=0.978114
# INFO:root:Epoch[1] Batch [156]	Speed: 30683.17 samples/sec	Train-RMSE=0.949212
# INFO:root:Epoch[1] Batch [312]	Speed: 30868.07 samples/sec	Train-RMSE=0.951608
# INFO:root:Epoch[1] Batch [468]	Speed: 31483.75 samples/sec	Train-RMSE=0.955808
# INFO:root:Epoch[1] Batch [624]	Speed: 34920.70 samples/sec	Train-RMSE=0.959489
# INFO:root:Epoch[1] Batch [780]	Speed: 32155.51 samples/sec	Train-RMSE=0.945665
# INFO:root:Epoch[1] Batch [936]	Speed: 31340.62 samples/sec	Train-RMSE=0.944534
# INFO:root:Epoch[1] Batch [1092]	Speed: 31162.70 samples/sec	Train-RMSE=0.945014
# INFO:root:Epoch[1] Batch [1248]	Speed: 31244.24 samples/sec	Train-RMSE=0.951440
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=2.563
# INFO:root:Epoch[1] Validation-RMSE=0.975165
# INFO:root:Epoch[2] Batch [156]	Speed: 35262.69 samples/sec	Train-RMSE=0.942642
# INFO:root:Epoch[2] Batch [312]	Speed: 34887.02 samples/sec	Train-RMSE=0.933122
# INFO:root:Epoch[2] Batch [468]	Speed: 35088.57 samples/sec	Train-RMSE=0.944248
# INFO:root:Epoch[2] Batch [624]	Speed: 34988.95 samples/sec	Train-RMSE=0.943167
# INFO:root:Epoch[2] Batch [780]	Speed: 34955.04 samples/sec	Train-RMSE=0.943710
# INFO:root:Epoch[2] Batch [936]	Speed: 30766.38 samples/sec	Train-RMSE=0.928660
# INFO:root:Epoch[2] Batch [1092]	Speed: 30604.26 samples/sec	Train-RMSE=0.948441
# INFO:root:Epoch[2] Batch [1248]	Speed: 30682.32 samples/sec	Train-RMSE=0.943952
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=2.442
# INFO:root:Epoch[2] Validation-RMSE=0.962911
# INFO:root:Epoch[3] Batch [156]	Speed: 30835.95 samples/sec	Train-RMSE=0.920814
# INFO:root:Epoch[3] Batch [312]	Speed: 31063.53 samples/sec	Train-RMSE=0.926121
# INFO:root:Epoch[3] Batch [468]	Speed: 30694.21 samples/sec	Train-RMSE=0.936737
# INFO:root:Epoch[3] Batch [624]	Speed: 30565.19 samples/sec	Train-RMSE=0.945118
# INFO:root:Epoch[3] Batch [780]	Speed: 30898.93 samples/sec	Train-RMSE=0.933481
# INFO:root:Epoch[3] Batch [936]	Speed: 30642.78 samples/sec	Train-RMSE=0.939749
# INFO:root:Epoch[3] Batch [1092]	Speed: 31263.29 samples/sec	Train-RMSE=0.947351
# INFO:root:Epoch[3] Batch [1248]	Speed: 31130.36 samples/sec	Train-RMSE=0.945224
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=2.630
# INFO:root:Epoch[3] Validation-RMSE=0.957273
# INFO:root:Epoch[4] Batch [156]	Speed: 31526.08 samples/sec	Train-RMSE=0.918031
# INFO:root:Epoch[4] Batch [312]	Speed: 30568.47 samples/sec	Train-RMSE=0.930736
# INFO:root:Epoch[4] Batch [468]	Speed: 30525.11 samples/sec	Train-RMSE=0.942186
# INFO:root:Epoch[4] Batch [624]	Speed: 31053.46 samples/sec	Train-RMSE=0.932028
# INFO:root:Epoch[4] Batch [780]	Speed: 31089.75 samples/sec	Train-RMSE=0.939669
# INFO:root:Epoch[4] Batch [936]	Speed: 30973.30 samples/sec	Train-RMSE=0.938523
# INFO:root:Epoch[4] Batch [1092]	Speed: 30370.52 samples/sec	Train-RMSE=0.933891
# INFO:root:Epoch[4] Batch [1248]	Speed: 30878.11 samples/sec	Train-RMSE=0.929265
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=2.630
# INFO:root:Epoch[4] Validation-RMSE=0.955076
# INFO:root:Epoch[5] Batch [156]	Speed: 30856.24 samples/sec	Train-RMSE=0.924776
# INFO:root:Epoch[5] Batch [312]	Speed: 31165.80 samples/sec	Train-RMSE=0.919315
# INFO:root:Epoch[5] Batch [468]	Speed: 31213.56 samples/sec	Train-RMSE=0.948400
# INFO:root:Epoch[5] Batch [624]	Speed: 31150.55 samples/sec	Train-RMSE=0.930602
# INFO:root:Epoch[5] Batch [780]	Speed: 31274.08 samples/sec	Train-RMSE=0.935643
# INFO:root:Epoch[5] Batch [936]	Speed: 31413.41 samples/sec	Train-RMSE=0.932529
# INFO:root:Epoch[5] Batch [1092]	Speed: 31318.90 samples/sec	Train-RMSE=0.938194
# INFO:root:Epoch[5] Batch [1248]	Speed: 31095.54 samples/sec	Train-RMSE=0.926393
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=2.603
# INFO:root:Epoch[5] Validation-RMSE=0.957072
# INFO:root:Epoch[6] Batch [156]	Speed: 30959.40 samples/sec	Train-RMSE=0.939036
# INFO:root:Epoch[6] Batch [312]	Speed: 30305.79 samples/sec	Train-RMSE=0.917075
# INFO:root:Epoch[6] Batch [468]	Speed: 31005.73 samples/sec	Train-RMSE=0.938251
# INFO:root:Epoch[6] Batch [624]	Speed: 30332.31 samples/sec	Train-RMSE=0.939276
# INFO:root:Epoch[6] Batch [780]	Speed: 31259.40 samples/sec	Train-RMSE=0.924594
# INFO:root:Epoch[6] Batch [936]	Speed: 31219.99 samples/sec	Train-RMSE=0.926362
# INFO:root:Epoch[6] Batch [1092]	Speed: 32942.02 samples/sec	Train-RMSE=0.924488
# INFO:root:Epoch[6] Batch [1248]	Speed: 34970.60 samples/sec	Train-RMSE=0.926823
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=2.573
# INFO:root:Epoch[6] Validation-RMSE=0.953832
# INFO:root:Epoch[7] Batch [156]	Speed: 34790.73 samples/sec	Train-RMSE=0.914066
# INFO:root:Epoch[7] Batch [312]	Speed: 34857.54 samples/sec	Train-RMSE=0.938872
# INFO:root:Epoch[7] Batch [468]	Speed: 34974.02 samples/sec	Train-RMSE=0.930738
# INFO:root:Epoch[7] Batch [624]	Speed: 34889.08 samples/sec	Train-RMSE=0.918107
# INFO:root:Epoch[7] Batch [780]	Speed: 34933.17 samples/sec	Train-RMSE=0.916927
# INFO:root:Epoch[7] Batch [936]	Speed: 34738.06 samples/sec	Train-RMSE=0.929646
# INFO:root:Epoch[7] Batch [1092]	Speed: 34856.32 samples/sec	Train-RMSE=0.929019
# INFO:root:Epoch[7] Batch [1248]	Speed: 34863.02 samples/sec	Train-RMSE=0.938901
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=2.333
# INFO:root:Epoch[7] Validation-RMSE=0.963170
# INFO:root:Epoch[8] Batch [156]	Speed: 35032.45 samples/sec	Train-RMSE=0.925915
# INFO:root:Epoch[8] Batch [312]	Speed: 34781.54 samples/sec	Train-RMSE=0.923126
# INFO:root:Epoch[8] Batch [468]	Speed: 34741.81 samples/sec	Train-RMSE=0.932726
# INFO:root:Epoch[8] Batch [624]	Speed: 34974.63 samples/sec	Train-RMSE=0.929655
# INFO:root:Epoch[8] Batch [780]	Speed: 34901.76 samples/sec	Train-RMSE=0.921560
# INFO:root:Epoch[8] Batch [936]	Speed: 34887.63 samples/sec	Train-RMSE=0.929801
# INFO:root:Epoch[8] Batch [1092]	Speed: 34707.05 samples/sec	Train-RMSE=0.929785
# INFO:root:Epoch[8] Batch [1248]	Speed: 34832.37 samples/sec	Train-RMSE=0.929096
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=2.336
# INFO:root:Epoch[8] Validation-RMSE=0.965062
# INFO:root:Epoch[9] Batch [156]	Speed: 34933.38 samples/sec	Train-RMSE=0.909513
# INFO:root:Epoch[9] Batch [312]	Speed: 34673.05 samples/sec	Train-RMSE=0.933655
# INFO:root:Epoch[9] Batch [468]	Speed: 34769.87 samples/sec	Train-RMSE=0.929988
# INFO:root:Epoch[9] Batch [624]	Speed: 34876.79 samples/sec	Train-RMSE=0.916171
# INFO:root:Epoch[9] Batch [780]	Speed: 35084.13 samples/sec	Train-RMSE=0.918759
# INFO:root:Epoch[9] Batch [936]	Speed: 35038.72 samples/sec	Train-RMSE=0.918020
# INFO:root:Epoch[9] Batch [1092]	Speed: 34762.51 samples/sec	Train-RMSE=0.927458
# INFO:root:Epoch[9] Batch [1248]	Speed: 34990.71 samples/sec	Train-RMSE=0.941439
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=2.333
# INFO:root:Epoch[9] Validation-RMSE=0.951576

# %% [markdown]
# Adding dropout layers to relief the over-fitting.

# %%
def get_one_layer_dropout_mlp(hidden, k):
    # input
    user = mx.symbol.Variable('user')
    item = mx.symbol.Variable('item')
    score = mx.symbol.Variable('score')
    # user latent features
    user = mx.symbol.Embedding(data = user, input_dim = max_user, output_dim = k)
    user = mx.symbol.FullyConnected(data = user, num_hidden = hidden)
    user = mx.symbol.Dropout(data=user, p=0.5)
    # item latent features
    item = mx.symbol.Embedding(data = item, input_dim = max_item, output_dim = k)
    item = mx.symbol.FullyConnected(data = item, num_hidden = hidden)
    item = mx.symbol.Dropout(data=item, p=0.5)    
    # predict by the inner product
    pred = user * item
    pred = mx.symbol.sum_axis(data = pred, axis = 1)
    pred = mx.symbol.Flatten(data = pred)
    # loss layer
    pred = mx.symbol.LinearRegressionOutput(data = pred, label = score)
    return pred
train(get_one_layer_mlp(256, 512), batch_size=64, num_epoch=10, learning_rate=.02)
# Out:
# INFO:root:Start training with [gpu(0)]
# INFO:root:Epoch[0] Batch [156]	Speed: 29301.10 samples/sec	Train-RMSE=1.790682
# INFO:root:Epoch[0] Batch [312]	Speed: 29281.08 samples/sec	Train-RMSE=1.113848
# INFO:root:Epoch[0] Batch [468]	Speed: 29358.50 samples/sec	Train-RMSE=1.060094
# INFO:root:Epoch[0] Batch [624]	Speed: 29291.55 samples/sec	Train-RMSE=1.005032
# INFO:root:Epoch[0] Batch [780]	Speed: 29233.50 samples/sec	Train-RMSE=0.975966
# INFO:root:Epoch[0] Batch [936]	Speed: 29310.04 samples/sec	Train-RMSE=0.982252
# INFO:root:Epoch[0] Batch [1092]	Speed: 29440.38 samples/sec	Train-RMSE=0.972627
# INFO:root:Epoch[0] Batch [1248]	Speed: 29424.34 samples/sec	Train-RMSE=0.972099
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=2.768
# INFO:root:Epoch[0] Validation-RMSE=0.983640
# INFO:root:Epoch[1] Batch [156]	Speed: 22813.32 samples/sec	Train-RMSE=0.944569
# INFO:root:Epoch[1] Batch [312]	Speed: 22577.30 samples/sec	Train-RMSE=0.950992
# INFO:root:Epoch[1] Batch [468]	Speed: 22614.69 samples/sec	Train-RMSE=0.957585
# INFO:root:Epoch[1] Batch [624]	Speed: 22576.14 samples/sec	Train-RMSE=0.933718
# INFO:root:Epoch[1] Batch [780]	Speed: 22581.64 samples/sec	Train-RMSE=0.953794
# INFO:root:Epoch[1] Batch [936]	Speed: 22460.23 samples/sec	Train-RMSE=0.958251
# INFO:root:Epoch[1] Batch [1092]	Speed: 22577.51 samples/sec	Train-RMSE=0.947528
# INFO:root:Epoch[1] Batch [1248]	Speed: 22556.34 samples/sec	Train-RMSE=0.941649
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=3.582
# INFO:root:Epoch[1] Validation-RMSE=0.968206
# INFO:root:Epoch[2] Batch [156]	Speed: 22787.39 samples/sec	Train-RMSE=0.930318
# INFO:root:Epoch[2] Batch [312]	Speed: 22674.01 samples/sec	Train-RMSE=0.941576
# INFO:root:Epoch[2] Batch [468]	Speed: 22767.96 samples/sec	Train-RMSE=0.944394
# INFO:root:Epoch[2] Batch [624]	Speed: 22708.45 samples/sec	Train-RMSE=0.933607
# INFO:root:Epoch[2] Batch [780]	Speed: 22713.47 samples/sec	Train-RMSE=0.937826
# INFO:root:Epoch[2] Batch [936]	Speed: 22606.24 samples/sec	Train-RMSE=0.950298
# INFO:root:Epoch[2] Batch [1092]	Speed: 22610.39 samples/sec	Train-RMSE=0.937505
# INFO:root:Epoch[2] Batch [1248]	Speed: 22522.81 samples/sec	Train-RMSE=0.942826
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=3.570
# INFO:root:Epoch[2] Validation-RMSE=0.961135
# INFO:root:Epoch[3] Batch [156]	Speed: 22609.20 samples/sec	Train-RMSE=0.934108
# INFO:root:Epoch[3] Batch [312]	Speed: 22430.77 samples/sec	Train-RMSE=0.930039
# INFO:root:Epoch[3] Batch [468]	Speed: 22459.93 samples/sec	Train-RMSE=0.921241
# INFO:root:Epoch[3] Batch [624]	Speed: 22508.39 samples/sec	Train-RMSE=0.935312
# INFO:root:Epoch[3] Batch [780]	Speed: 29143.73 samples/sec	Train-RMSE=0.945226
# INFO:root:Epoch[3] Batch [936]	Speed: 29230.33 samples/sec	Train-RMSE=0.941457
# INFO:root:Epoch[3] Batch [1092]	Speed: 29360.99 samples/sec	Train-RMSE=0.946398
# INFO:root:Epoch[3] Batch [1248]	Speed: 29240.09 samples/sec	Train-RMSE=0.937095
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=3.188
# INFO:root:Epoch[3] Validation-RMSE=0.961336
# INFO:root:Epoch[4] Batch [156]	Speed: 29343.64 samples/sec	Train-RMSE=0.933257
# INFO:root:Epoch[4] Batch [312]	Speed: 29160.58 samples/sec	Train-RMSE=0.917006
# INFO:root:Epoch[4] Batch [468]	Speed: 29216.30 samples/sec	Train-RMSE=0.942208
# INFO:root:Epoch[4] Batch [624]	Speed: 29259.11 samples/sec	Train-RMSE=0.937070
# INFO:root:Epoch[4] Batch [780]	Speed: 29183.52 samples/sec	Train-RMSE=0.929886
# INFO:root:Epoch[4] Batch [936]	Speed: 29283.23 samples/sec	Train-RMSE=0.942090
# INFO:root:Epoch[4] Batch [1092]	Speed: 29315.05 samples/sec	Train-RMSE=0.925818
# INFO:root:Epoch[4] Batch [1248]	Speed: 29301.72 samples/sec	Train-RMSE=0.946179
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=2.772
# INFO:root:Epoch[4] Validation-RMSE=0.956032
# INFO:root:Epoch[5] Batch [156]	Speed: 29654.36 samples/sec	Train-RMSE=0.921894
# INFO:root:Epoch[5] Batch [312]	Speed: 29407.17 samples/sec	Train-RMSE=0.928768
# INFO:root:Epoch[5] Batch [468]	Speed: 29363.23 samples/sec	Train-RMSE=0.923658
# INFO:root:Epoch[5] Batch [624]	Speed: 29401.80 samples/sec	Train-RMSE=0.920641
# INFO:root:Epoch[5] Batch [780]	Speed: 29421.04 samples/sec	Train-RMSE=0.929944
# INFO:root:Epoch[5] Batch [936]	Speed: 29321.84 samples/sec	Train-RMSE=0.939287
# INFO:root:Epoch[5] Batch [1092]	Speed: 29435.78 samples/sec	Train-RMSE=0.947566
# INFO:root:Epoch[5] Batch [1248]	Speed: 29440.75 samples/sec	Train-RMSE=0.935860
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=2.758
# INFO:root:Epoch[5] Validation-RMSE=0.963435
# INFO:root:Epoch[6] Batch [156]	Speed: 29453.84 samples/sec	Train-RMSE=0.924084
# INFO:root:Epoch[6] Batch [312]	Speed: 29369.97 samples/sec	Train-RMSE=0.932678
# INFO:root:Epoch[6] Batch [468]	Speed: 29396.87 samples/sec	Train-RMSE=0.940401
# INFO:root:Epoch[6] Batch [624]	Speed: 29553.95 samples/sec	Train-RMSE=0.922988
# INFO:root:Epoch[6] Batch [780]	Speed: 29427.96 samples/sec	Train-RMSE=0.927942
# INFO:root:Epoch[6] Batch [936]	Speed: 28665.02 samples/sec	Train-RMSE=0.930397
# INFO:root:Epoch[6] Batch [1092]	Speed: 28085.11 samples/sec	Train-RMSE=0.928915
# INFO:root:Epoch[6] Batch [1248]	Speed: 29463.06 samples/sec	Train-RMSE=0.928845
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=2.783
# INFO:root:Epoch[6] Validation-RMSE=0.953191
# INFO:root:Epoch[7] Batch [156]	Speed: 29812.06 samples/sec	Train-RMSE=0.923179
# INFO:root:Epoch[7] Batch [312]	Speed: 29008.01 samples/sec	Train-RMSE=0.932230
# INFO:root:Epoch[7] Batch [468]	Speed: 29442.55 samples/sec	Train-RMSE=0.915791
# INFO:root:Epoch[7] Batch [624]	Speed: 29462.81 samples/sec	Train-RMSE=0.930312
# INFO:root:Epoch[7] Batch [780]	Speed: 29415.23 samples/sec	Train-RMSE=0.922857
# INFO:root:Epoch[7] Batch [936]	Speed: 29436.57 samples/sec	Train-RMSE=0.926345
# INFO:root:Epoch[7] Batch [1092]	Speed: 29437.35 samples/sec	Train-RMSE=0.922830
# INFO:root:Epoch[7] Batch [1248]	Speed: 29366.44 samples/sec	Train-RMSE=0.932184
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=2.761
# INFO:root:Epoch[7] Validation-RMSE=0.955406
# INFO:root:Epoch[8] Batch [156]	Speed: 29679.83 samples/sec	Train-RMSE=0.915235
# INFO:root:Epoch[8] Batch [312]	Speed: 29480.73 samples/sec	Train-RMSE=0.926871
# INFO:root:Epoch[8] Batch [468]	Speed: 29419.22 samples/sec	Train-RMSE=0.918528
# INFO:root:Epoch[8] Batch [624]	Speed: 29449.15 samples/sec	Train-RMSE=0.926639
# INFO:root:Epoch[8] Batch [780]	Speed: 29444.12 samples/sec	Train-RMSE=0.914554
# INFO:root:Epoch[8] Batch [936]	Speed: 29494.75 samples/sec	Train-RMSE=0.928927
# INFO:root:Epoch[8] Batch [1092]	Speed: 29466.19 samples/sec	Train-RMSE=0.929132
# INFO:root:Epoch[8] Batch [1248]	Speed: 29537.06 samples/sec	Train-RMSE=0.939788
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=2.752
# INFO:root:Epoch[8] Validation-RMSE=0.959778
# INFO:root:Epoch[9] Batch [156]	Speed: 29699.26 samples/sec	Train-RMSE=0.916807
# INFO:root:Epoch[9] Batch [312]	Speed: 29539.41 samples/sec	Train-RMSE=0.910764
# INFO:root:Epoch[9] Batch [468]	Speed: 29567.49 samples/sec	Train-RMSE=0.927473
# INFO:root:Epoch[9] Batch [624]	Speed: 29540.48 samples/sec	Train-RMSE=0.917609
# INFO:root:Epoch[9] Batch [780]	Speed: 29887.83 samples/sec	Train-RMSE=0.927466
# INFO:root:Epoch[9] Batch [936]	Speed: 29868.52 samples/sec	Train-RMSE=0.925121
# INFO:root:Epoch[9] Batch [1092]	Speed: 29969.65 samples/sec	Train-RMSE=0.929185
# INFO:root:Epoch[9] Batch [1248]	Speed: 29789.65 samples/sec	Train-RMSE=0.929312
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=2.731
# INFO:root:Epoch[9] Validation-RMSE=0.947868

# %% [markdown]
# ## Acknowledgement
#
# This tutorial is based on examples from [xlvector/github](https://github.com/xlvector/).
